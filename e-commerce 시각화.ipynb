# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data_2014=pd.read_excel('C://Users//Administrator//Desktop//us superstore//2014클래식.xlsx')
data_2015=pd.read_excel('C://Users//Administrator//Desktop//us superstore//2015클래식.xlsx')
data_2016=pd.read_excel('C://Users//Administrator//Desktop//us superstore//2016클래식.xlsx')

data_2014_1=pd.read_excel('C://Users//Administrator//Desktop//us superstore//클래식2014.xlsx')
rol_2015=pd.read_excel('C://Users//Administrator//Desktop//us superstore//2015부터2017롤링.xlsx')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:214: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
data_2014.set_index('최초구매월',inplace=True)
data_2015.set_index('최초구매월',inplace=True)
data_2016.set_index('최초구매월',inplace=True)
data_2014_1.set_index('최초구매월',inplace=True)
rol_2015.set_index('최초구매월',inplace=True)

# %%
data_2014=data_2014.drop(columns='month0')
data_2015=data_2015.drop(columns='month0')
data_2016=data_2016.drop(columns='month0')
rol_2015=rol_2015.drop(columns='month0')

# %%
data_2014_1=data_2014_1.drop(columns='month0')

# %%
d_2015=pd.read_excel('C://Users//Administrator//Desktop//us superstore//2015부터2017까지.xlsx')

# %%
최초구매월=['201501','2015-02','2015-03','2015-04','2015-05','2015-06','2015-07','2015-08','2015-09','2015-10','2015-11','2015-12',]

# %%
rol_2015
# Out:
#         pct_1  pct_2  pct_3  pct_4  pct_5  pct_6  pct_7  pct_8  pct_9  pct_10  \
# 최초구매월
# 201501      1      1   1.00   1.00   1.00   1.00   1.00   1.00   1.00    1.00
# 201502      1      1   1.00   1.00   1.00   1.00   1.00   1.00   1.00    1.00
# 201503      1      1   1.00   1.00   1.00   1.00   1.00   1.00   1.00    1.00
# 201504      1      1   1.00   1.00   1.00   1.00   1.00   1.00   1.00    1.00
# 201505      1      1   1.00   1.00   1.00   1.00   1.00   1.00   1.00    1.00
# 201506      1      1   1.00   1.00   1.00   1.00   1.00   1.00   0.92    0.92
# 201507      1      1   1.00   1.00   1.00   1.00   1.00   1.00   1.00    1.00
# 201508      1      1   1.00   1.00   1.00   1.00   1.00   1.00   1.00    1.00
# 201509      1      1   1.00   1.00   0.94   0.94   0.94   0.94   0.94    0.94
# 201510      1      1   0.89   0.89   0.89   0.89   0.89   0.89   0.89    0.89
# 201511      1      1   1.00   1.00   1.00   1.00   1.00   1.00   1.00    1.00
# ...

# %%
'''
plt.figure(figsize=(12, 6))
plt.xlabel('최초구매월')
plt.ylabel('pct_month')
plt.plot(최초구매월,d_2015['pct_1'],marker='o',markersize=4,label='pct_1')
plt.plot(최초구매월,d_2015['pct_2'],':',marker='o',markersize=4,label='pct_2')
plt.plot(최초구매월,d_2015['pct_3'],marker='o',markersize=4,label='pct_3')
plt.plot(최초구매월,d_2015['pct_4'],marker='o',markersize=4,label='pct_4')
plt.plot(최초구매월,d_2015['pct_5'],marker='o',markersize=4,label='pct_5')
plt.plot(최초구매월,d_2015['pct_6'],marker='o',markersize=4,label='pct_6')
plt.plot(최초구매월,d_2015['pct_7'],marker='o',markersize=4,label='pct_7')
plt.plot(최초구매월,d_2015['pct_8'],marker='o',markersize=4,label='pct_8')
plt.plot(최초구매월,d_2015['pct_9'],marker='o',markersize=4,label='pct_9')
plt.plot(최초구매월,d_2015['pct_10'],marker='o',markersize=4,label='pct_10')
plt.plot(최초구매월,d_2015['pct_11'],'--',marker='o',markersize=4,label='pct_11')
plt.plot(최초구매월,d_2015['pct_12'],marker='o',markersize=4,label='pct_12')
plt.legend(ncol=3)

plt.show()

'''
# Out:
# "\nplt.figure(figsize=(12, 6))\nplt.xlabel('최초구매월')\nplt.ylabel('pct_month')\nplt.plot(최초구매월,d_2015['pct_1'],marker='o',markersize=4,label='pct_1')\nplt.plot(최초구매월,d_2015['pct_2'],':',marker='o',markersize=4,label='pct_2')\nplt.plot(최초구매월,d_2015['pct_3'],marker='o',markersize=4,label='pct_3')\nplt.plot(최초구매월,d_2015['pct_4'],marker='o',markersize=4,label='pct_4')\nplt.plot(최초구매월,d_2015['pct_5'],marker='o',markersize=4,label='pct_5')\nplt.plot(최초구매월,d_2015['pct_6'],marker='o',markersize=4,label='pct_6')\nplt.plot(최초구매월,d_2015['pct_7'],marker='o',markersize=4,label='pct_7')\nplt.plot(최초구매월,d_2015['pct_8'],marker='o',markersize=4,label='pct_8')\nplt.plot(최초구매월,d_2015['pct_9'],marker='o',markersize=4,label='pct_9')\nplt.plot(최초구매월,d_2015['pct_10'],marker='o',markersize=4,label='pct_10')\nplt.plot(최초구매월,d_2015['pct_11'],'--',marker='o',markersize=4,label='pct_11')\nplt.plot(최초구매월,d_2015['pct_12'],marker='o',markersize=4,label='pct_12')\nplt.legend(ncol=3)\n\nplt.show()\n\n"

# %%
plt.figure(figsize=(12, 6))
plt.xlabel('최초구매월')
plt.ylabel('pct_month')

plt.plot(최초구매월,d_2015['pct_1y 1m'],marker='o',markersize=4,label='pct_1y 1m')
plt.plot(최초구매월,d_2015['pct_1y 2m'],marker='o',markersize=4,label='pct_1y 2m')
plt.plot(최초구매월,d_2015['pct_1y 3m'],marker='o',markersize=4,label='pct_1y 3m')
plt.plot(최초구매월,d_2015['pct_1y 4m'],marker='o',markersize=4,label='pct_1y 4m')
plt.plot(최초구매월,d_2015['pct_1y 5m'],':',marker='o',markersize=4,label='pct_1y 5m')
plt.plot(최초구매월,d_2015['pct_1y 6m'],marker='o',markersize=4,label='pct_1y 6m')
plt.plot(최초구매월,d_2015['pct_1y 7m'],marker='o',markersize=4,label='pct_1y 7m')
plt.plot(최초구매월,d_2015['pct_1y 8m'],marker='o',markersize=4,label='pct_1y 8m')
plt.plot(최초구매월,d_2015['pct_1y 9m'],marker='o',markersize=4,label='pct_1y 9m')
plt.plot(최초구매월,d_2015['pct_1y 10m'],marker='o',markersize=4,label='pct_1y 10m')
plt.plot(최초구매월,d_2015['pct_1y 11m'],marker='o',markersize=4,label='pct_1y 11m')
plt.plot(최초구매월,d_2015['pct_1y 12m'],'--',marker='o',markersize=4,label='pct_1y 12m')
plt.legend(ncol=6)

# %%
plt.figure(figsize=(12, 6))
plt.xlabel('최초구매월')
plt.ylabel('pct_month')

plt.plot(최초구매월,d_2015['pct_2y 1m'],marker='o',markersize=4,label='pct_2y 1m')
plt.plot(최초구매월,d_2015['pct_2y 2m'],marker='o',markersize=4,label='pct_2y 2m')
plt.plot(최초구매월,d_2015['pct_2y 3m'],'--',marker='o',markersize=4,label='pct_2y 3m')
plt.plot(최초구매월,d_2015['pct_2y 4m'],marker='o',markersize=4,label='pct_2y 4m')
plt.plot(최초구매월,d_2015['pct_2y 5m'],marker='o',markersize=4,label='pct_2y 5m')
plt.plot(최초구매월,d_2015['pct_2y 6m'],marker='o',markersize=4,label='pct_2y 6m')
plt.plot(최초구매월,d_2015['pct_2y 7m'],marker='o',markersize=4,label='pct_2y 7m')
plt.plot(최초구매월,d_2015['pct_2y 8m'],marker='o',markersize=4,label='pct_2y 8m')
plt.plot(최초구매월,d_2015['pct_2y 9m'],marker='o',markersize=4,label='pct_2y 9m')
plt.plot(최초구매월,d_2015['pct_2y 10m'],marker='o',markersize=4,label='pct_2y 10m')
plt.plot(최초구매월,d_2015['pct_2y 11m'],marker='o',markersize=4,label='pct_2y 11m')
plt.plot(최초구매월,d_2015['pct_2y 12m'],marker='o',markersize=4,label='pct_2y 12m')
plt.legend(ncol=6)

# %%
d_2015.set_index('최초구매월',inplace=True)
d_2015=d_2015.drop(columns='month0')

# %%
d_2015=d_2015.transpose()

# %%
#  시각화
#plt.figure(figsize=(36, 12))
#plt.title("Cohort Analysis - 리텐션분석", fontsize=20)

# 한글패치는 미리미리 ~ 
#sns.heatmap(d_2015, annot=True, fmt=".0%",annot_kws={'size':15},linewidth=0.8)
#plt.show()

# %%
#롤링 리텐션 시각화
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(36,12))
plt.title("Rolling Retention(2015~2017)" ,fontsize=20)
sns.heatmap(rol_2015, annot=True, fmt=".0%",annot_kws={'size':15},linewidth=0.8)
plt.savefig('C://Users//Administrator//Desktop//us superstore//rolling2015.png')
